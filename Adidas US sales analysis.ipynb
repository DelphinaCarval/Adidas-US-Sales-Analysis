# %% [markdown]
# # Adidas US Sales Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\Delphina\Desktop\DAB303MARKETING\INDIVIDUAL PROJECT\Adidas US Sales Datasets.xlsx")

# %% [markdown]
# # About the dataset
#
# With a solid brand recognition and a devoted client base, Adidas is a market leader in the sports footwear and clothing sector. Adidas wants to comprehend the interests and habits of its clients so that it may use this knowledge to develop specialised marketing strategies. Adidas has gathered and examined sales information from the US market in order to accomplish this aim. The Adidas US Sales dataset will be described in general terms in this proposal, along with a marketing initiative that makes use of the data to accomplish goals.
# The Adidas US Sales dataset includes sales information for Adidas goods on the US market between 2020 and 2021. Dataset details on product type, product category, gender, price, and sales income are included. Moreover, the dataset contains data on the sales method, such as in-store sales, internet sales, and outlet sales. The collection is extensive and offers a lot of data that may be utilised to learn more about client behaviour and preferences.
# Dataset Link: https://data.world/stellabigail/adidas-us-sales-datasets

# %% [markdown]
# # OBJECTIVE
#
# The objective for Adidas US sales data analysis is to gain insights into the sales performance of Adidas products in the US market, identify trends in consumer behavior and preferences, and make data-driven decisions to optimize marketing and sales strategies by analyzing factors such as product sales by category, region, and store and  sales trends over time .The goal is to use the insights gained from the analysis to develop effective strategies for increasing sales and market share, improving customer satisfaction, and enhancing brand loyalty.

# %% [markdown]
# # Exploratory data analysis

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# ...

# %% [markdown]
# # Data cleaning

# %%
# Drop the first four rows and first two columns 
df1 = df.drop(index=range(4), columns=df.columns[:1])

# Reset the index
df1 = df1.reset_index(drop=True)

df1.head()
# Out:
#     Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Foot Locker    1185732  2020-01-01 00:00:00  Northeast   New York
# 1  Foot Locker    1185732  2020-01-02 00:00:00  Northeast   New York
# 2  Foot Locker    1185732  2020-01-03 00:00:00  Northeast   New York
# 3  Foot Locker    1185732  2020-01-04 00:00:00  Northeast   New York
# 4  Foot Locker    1185732  2020-01-05 00:00:00  Northeast   New York
#
#   Unnamed: 6                 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0   New York      Men's Street Footwear         50       1200      600000
# 1   New York    Men's Athletic Footwear         50       1000      500000
# 2   New York    Women's Street Footwear         40       1000      400000
# 3   New York  Women's Athletic Footwear         45        850      382500
# 4   New York              Men's Apparel         60        900      540000
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0      300000         0.5    In-store
# ...

# %%
# Define a dictionary of old and new column names
new_names = {'Unnamed: 1': 'Retailer',
             'Unnamed: 2': 'Retailer ID',
             'Unnamed: 3': 'Invoice Date',
             'Unnamed: 4': 'Region',
             'Unnamed: 5': 'State',
             'Unnamed: 6': 'City',
             'Unnamed: 7': 'Product',
             'Unnamed: 8': 'Price per Unit',
             'Unnamed: 9': 'Units Sold',
             'Unnamed: 10': 'Total Sales',
             'Unnamed: 11': 'Operating Profit',
             'Unnamed: 12': 'Operating Margin',
             'Unnamed: 13': 'Sales Method'}

# Rename the columns of the dataframe
df1 = df1.rename(columns=new_names)

df1
# Out:
#          Retailer Retailer ID         Invoice Date     Region          State  \
# 0     Foot Locker     1185732  2020-01-01 00:00:00  Northeast       New York
# 1     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 2     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 3     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 4     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9643  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9647  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %%
# Convert the invoice date column to datetime format
df1['Invoice Date'] = pd.to_datetime(df1['Invoice Date'])

# Extract the year from the invoice date column and create a new column
df1['Year'] = df1['Invoice Date'].dt.year

# %%
df1.head()
# Out:
#       Retailer Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-01-05  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear             50       1200      600000
# 1    Men's Athletic Footwear             50       1000      500000
# 2    Women's Street Footwear             40       1000      400000
# 3  Women's Athletic Footwear             45        850      382500
# 4              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method  Year
# 0           300000              0.5     In-store  2020
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
#  13  Year              9648 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(12)
# memory usage: 1.0+ MB

# %% [markdown]
# Changing data types of columns

# %%
cols_to_convert = ['Price per Unit', 'Units Sold', 'Total Sales', 'Operating Profit', 'Operating Margin']

for col in cols_to_convert:
    df1[col] = pd.to_numeric(df1[col])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
#  13  Year              9648 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 1.0+ MB

# %%
# Statistical analysis of numerical columns
df1.describe()
# Out:
#        Price per Unit   Units Sold    Total Sales  Operating Profit  \
# count     9648.000000  9648.000000    9648.000000       9648.000000
# mean        45.216625   256.930037   93273.437500      34425.244761
# std         14.705397   214.252030  141916.016727      54193.113713
# min          7.000000     0.000000       0.000000          0.000000
# 25%         35.000000   106.000000    4254.500000       1921.752500
# 50%         45.000000   176.000000    9576.000000       4371.420000
# 75%         55.000000   350.000000  150000.000000      52062.500000
# max        110.000000  1275.000000  825000.000000     390000.000000
#
#        Operating Margin         Year
# count       9648.000000  9648.000000
# mean           0.422991  2020.865050
# std            0.097197     0.341688
# min            0.100000  2020.000000
# 25%            0.350000  2021.000000
# 50%            0.410000  2021.000000
# 75%            0.490000  2021.000000
# max            0.800000  2021.000000

# %%
# Check for null values in the dataframe
df1.isnull().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# Year                0
# dtype: int64

# %% [markdown]
# # Correlation matrix

# %%
corr_matrix = df1.corr()

# plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# C:\Users\Delphina\AppData\Local\Temp\ipykernel_20580\1460331403.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df1.corr()
# <AxesSubplot: >

# %% [markdown]
# # Plotting

# %%
# Group the data by state and calculate total sales for each state
state_sales = df1.groupby('State')['Total Sales'].sum()

# Create a horizontal bar chart of total sales by state
fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(state_sales.index, state_sales.values, height=0.5)
ax.set_xlabel('Total Sales(M$)')
ax.set_ylabel('State')
ax.set_title('Total Sales by State')

# Adjust the x-axis label font size
for label in ax.xaxis.get_ticklabels():
    label.set_fontsize(10)

plt.show()

# %% [markdown]
# Insight:-
# The horizontal bar graph shows the total sales for each state in the US for the Adidas brand. It is evident that New York, California, and Florida are the top-performing states with the highest sales. This information can be useful for Adidas to allocate resources and prioritize marketing efforts to maximize revenue in high-performing states. Additionally, it can help identify opportunities to improve sales in low-performing states and potentially expand the brand's reach.
#
# Recommendation:-
# Adidas should work with well-known social media influencers to promote their products. They should utilize digital advertising to reach out to potential clients who have expressed an interest in Adidas or comparable items. To appeal to socially concerned consumers , they should highlight commitment to sustainability and ethical production techniques and consider working with groups that promote social responsibility.

# %%
import calendar

# Calculate monthly sales
monthly_sales = df1.groupby([df1['Invoice Date'].dt.year, df1['Invoice Date'].dt.month])['Total Sales'].sum()
monthly_sales = monthly_sales.groupby(level=1).sum()
plt.plot(monthly_sales.values, color='blue', linewidth=2, marker='o', markersize=6)
plt.grid(True)
month_names = [calendar.month_name[i][:3] for i in range(1, 13)]
plt.xticks(range(12), month_names)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales(M$)', fontsize=12)
plt.title('Monthly Sales', fontsize=14)
for i, v in enumerate(monthly_sales.values):
    plt.text(i, v, "${:,.0f}".format(v), color='blue', fontweight='bold')

plt.show()

# %% [markdown]
# Insight:-
# The line graph shows how well Adidas products are selling each month . By analyzing the chart, We can see that sales are highest in July, August, and December, and lowest in March. This helps Adidas understand why sales are high or low and set goals to improve sales performance.
#
# Recommendation:-
# For months with highest sales plan marketing campaigns and product releases around these peak months to take advantage of increased customer demand . During these months, promote seasonal items, such as summer sporting apparel in July and August or winter sports shoes in December . whereas for months with lower sales . Consider partnering with other brands or organizations to create limited-time collaborations or events to generate excitement and drive sales . Identify reasons for low sales during these months by analyzing sales data, customer feedback, and market trends . Develop and promote products that are suited to the season or upcoming events during these months.

# %%
# Group the data by sales method and calculate total sales for each method
method_sales = df1.groupby('Sales Method')['Total Sales'].sum()

# Create a pie chart of sales method
plt.pie(method_sales.values, labels=method_sales.index, autopct='%1.1f%%')
plt.title('Sales Method')
plt.show()

# %% [markdown]
# Insight:-
# Based on the pie chart, in-store sales for the Adidas brand generate the highest revenue at 39.6%, followed by outlet sales at 32.8%, and online sales at 27.5%. This information can be useful for Adidas to allocate resources and prioritize their sales method, as well as to potentially identify opportunities to improve sales in low-performing methods.
#
# Recommendation :-
# Adidas could think about investing more resources in advertising and refining its in-store sales experience, since it appears to be the preferred mode of sales for customers. To encourage customers to purchase in-store, Adidas may consider giving unique in-store promotions or limited-edition products . Adidas, on the other hand, could consider investing in its online sales platform, as online purchasing is growing increasingly popular among customers and may be a potential development area . To enhance exposure and attract people to its website, Adidas should focus on improving its website's user experience, giving free or cheap delivery, and expanding its online marketing activities.

# %%
import matplotlib.pyplot as plt
sales_by_Product = df1.groupby('Product')['Total Sales'].sum()

plt.pie(sales_by_Product, labels=sales_by_Product.index, autopct='%1.1f%%')

plt.title('Distribution of Sales by Product Category')

plt.show()

# %% [markdown]
# Insight:-
# The pie chart shows the distribution of sales by product category for the Adidas brand. It is clear that Men's Street Footwear and Women's Apparel are the top-performing product categories with the highest sales percentages. On the other hand, Women's Athletic Footwear has the lowest sales percentage . This information can be used by Adidas to make informed decisions about inventory management and product development.
#
# Recommendation :-
# As Men's Street Footwear and Women’s apparel has highest sales it is important to ensure that these products are always in stock and available in various sizes and colors to meet customer demand. Furthermore , to increase the sales of women's athletic footwear adidas should offer more attractive designs and styles, partnering with athletes or fitness influencers, or promoting the benefits of wearing athletic footwear for women.

# %%
product_state_sales = df1.groupby(['Region','Product', ])['Total Sales'].sum().unstack()

ax = product_state_sales.plot(kind='barh', width=0.8)
ax.set_yticklabels(product_state_sales.index, rotation=0)
plt.ylabel('Product and Region')
plt.xlabel('Total Sales(M$)')
plt.title('Total Sales by Product and Region')
plt.legend(title='Region', bbox_to_anchor=(1.01, 1), loc='upper left')

plt.show()

# %% [markdown]
# Insight - Based on the grouped bar chart, we can see that Men's Athletic Footwear is the most popular product category in all regions except for the South, where Women's apparel has the highest total sales.We can also see that Women's athletic Footwear has lowest total sales in all regions. Also, we can see Midwest has lowest overall sales of all products as compared to other regions.this chart provides valuable information for businesses to better understand consumer preferences and make data-driven decisions to optimize their marketing and sales strategies for each region and product category.
#
# Recommendation- As  Men's Athletic Footwear is the most popular product category in all regions, Adidas should consider investing more resources into designing and marketing new products in this category. Along with this As Women's apparel has the highest total sales in the South, Adidas should consider expanding its offerings in this category to cater to the demand in this region. As Women's athletic Footwear has the lowest total sales in all regions, Adidas should consider investing in research and development to improve the design and quality of its women's athletic footwear products and increase marketing efforts to boost sales in this category. Finally, As the Midwest has the lowest overall sales of all products, Adidas should consider increasing its marketing efforts and offering promotions and discounts in this region to boost sales and increase market share.

# %% [markdown]
# # Conclusion
# By leveraging the above-mentioned insights and recommendations , Adidas can make data-driven decisions to optimize marketing and sales strategies, improve customer satisfaction, and enhance brand loyalty. Moreover, according to the analysis Adidas should focus on sales performance by category, region, and store, as well as sales trends over time, to develop effective strategies for increasing sales and market share in the US market.
